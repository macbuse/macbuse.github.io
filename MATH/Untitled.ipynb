# %%
import numpy as np

A = np.array([
    [8/9, 1/18,   1/18, 0],
    [2/3, 0,   1/3, 0],
    [2/3, 1/3, 0,   0],
    [0,   0,   1,   0]
], dtype=float)

print(A)
# Out:
# [[0.88888889 0.05555556 0.05555556 0.        ]
#  [0.66666667 0.         0.33333333 0.        ]
#  [0.66666667 0.33333333 0.         0.        ]
#  [0.         0.         1.         0.        ]]

# %%
S.eigenvalues
# Out:
# array([ 1.        ,  0.22222222, -0.33333333,  0.        ])

# %%
S = np.linalg.eig(A.T)
S.eigenvectors
# Out:
# array([[ 9.93127066e-01,  8.16496581e-01,  4.13882491e-17,
#          6.32455532e-01],
#        [ 8.27605889e-02, -4.08248290e-01, -7.07106781e-01,
#         -7.37864787e-01],
#        [ 8.27605889e-02, -4.08248290e-01,  7.07106781e-01,
#         -1.05409255e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          2.10818511e-01]])

# %%
A.T
# Out:
# array([[0.88888889, 0.66666667, 0.66666667, 0.        ],
#        [0.        , 0.        , 0.33333333, 0.        ],
#        [0.11111111, 0.33333333, 0.        , 1.        ],
#        [0.        , 0.        , 0.        , 0.        ]])

# %%
S.eigenvalues
# Out:
# array([ 1.        , -0.33333333,  0.22222222,  0.        ])

# %%
B = np.array([8/9,1/9,2/3,1/3]).reshape(2,2)

# %%
S = np.linalg.eig(B.T)

# %%
B.T @ S.eigenvectors
# Out:
# array([[ 0.98639392, -0.15713484],
#        [ 0.16439899,  0.15713484]])

# %%
S.eigenvectors
# Out:
# array([[ 0.98639392, -0.70710678],
#        [ 0.16439899,  0.70710678]])

# %%
S.eigenvalues
# Out:
# array([1.        , 0.22222222])

# %%
B
# Out:
# array([[0.88888889, 0.11111111],
#        [0.66666667, 0.33333333]])

# %%
B - np.identity(2)
# Out:
# array([[-0.11111111,  0.11111111],
#        [ 0.66666667, -0.66666667]])

# %%
B.T @ [6,1]
# Out:
# array([6., 1.])

# %%
0.98639392 / 0.16439899
# Out:
# 5.9999998783447515

# %%
A.T @ [6,.5,.5,0]
# Out:
# array([6. , 0.5, 0.5, 0. ])

# %%
A
# Out:
# array([[0.88888889, 0.05555556, 0.05555556, 0.        ],
#        [0.66666667, 0.        , 0.33333333, 0.        ],
#        [0.66666667, 0.33333333, 0.        , 0.        ],
#        [0.        , 0.        , 1.        , 0.        ]])

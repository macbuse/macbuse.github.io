# %%
import goose3
from goose3 import Goose

gg = Goose()

url = "https://www.theguardian.com/commentisfree/2025/dec/10/medical-students-hope-future-nhs"

goose_art = gg.extract(url=url) 
txt = goose_art.cleaned_text
print(txt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import goose3
#       2 from goose3 import Goose
#       4 gg = Goose()
#
# ModuleNotFoundError: No module named 'goose3'

# %%
import sys
sys.path
# Out:
# ['/home/macbuse/miniconda3/lib/python311.zip',
#  '/home/macbuse/miniconda3/lib/python3.11',
#  '/home/macbuse/miniconda3/lib/python3.11/lib-dynload',
#  '',
#  '/home/macbuse/notebooks/lib/python3.11/site-packages']

# %%
! pip install goose3
# Out:
# Collecting goose3
#   Using cached goose3-3.1.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from goose3) (2.32.5)
# Collecting Pillow (from goose3)
#   Downloading pillow-12.0.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting lxml (from goose3)
#   Downloading lxml-6.0.2-cp314-cp314-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Collecting cssselect (from goose3)
#   Using cached cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: beautifulsoup4 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from goose3) (4.14.3)
# Requirement already satisfied: python-dateutil in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from goose3) (2.9.0.post0)
# Collecting langdetect (from goose3)
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyahocorasick (from goose3)
#   Downloading pyahocorasick-2.2.0.tar.gz (103 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soupsieve>=1.6.1 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from beautifulsoup4->goose3) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from beautifulsoup4->goose3) (4.15.0)
# Requirement already satisfied: six in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from langdetect->goose3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from requests->goose3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from requests->goose3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from requests->goose3) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from requests->goose3) (2025.11.12)
# Using cached goose3-3.1.21-py3-none-any.whl (114 kB)
# Using cached cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading lxml-6.0.2-cp314-cp314-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 941.7 kB/s  0:00:05 eta 0:00:010:00:01
# Downloading pillow-12.0.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 955.4 kB/s  0:00:07965.8 kB/s eta 0:00:01
# Building wheels for collected packages: langdetect, pyahocorasick
#   Building wheel for langdetect (pyproject.toml) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993332 sha256=8a6366d7a952e09dbaa5c98b597b52efe5a8e4bcf4ba31cf213e0e8451c828e5
#   Stored in directory: /home/macbuse/.cache/pip/wheels/13/60/5a/f2012969b3f7413b62b7b7063d6c9b45c93004a978cbe8ea2f
#   Building wheel for pyahocorasick (pyproject.toml) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-2.2.0-cp314-cp314-linux_x86_64.whl size=36325 sha256=8f2fcd13a1b80ce2a18ed009eb8905f416a9b4e3b8a118a67493c40e18ccb0e2
#   Stored in directory: /home/macbuse/.cache/pip/wheels/f3/53/8e/319a842ead1914dbda8e821dff59c75f393a8d34a2dbfc1b35
# Successfully built langdetect pyahocorasick
# Installing collected packages: pyahocorasick, Pillow, lxml, langdetect, cssselect, goose3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [goose3]━━━━ 5/6 [goose3]ect]ow]
# Successfully installed Pillow-12.0.0 cssselect-1.3.0 goose3-3.1.21 langdetect-1.0.9 lxml-6.0.2 pyahocorasick-2.2.0

# %%
from platform import python_version
print(python_version())
# Out:
# 3.11.11

# %%
import numpy as np

def Farey(n):
    F_n = np.array([[0,1], [1,1]],dtype=int)
    for k in range(n):
        tmp = np.zeros((2*F_n.shape[0]-1,2),dtype=int)
        # copy F_n in 
        tmp[::2,] = F_n
        # add medians in
        tmp[1::2,] = F_n[:-1] + F_n[1:]
        F_n = tmp
    return F_n

QQ = Farey(4)

# %%
A = np.ones((2,2))
C = A.copy()
A[1,0] = 0
A[0,1] = .3
B = A.copy()
B[0,1] = -.3

A@C@B
# Out:
# array([[1.3 , 0.91],
#        [1.  , 0.7 ]])

# %%
F = [1,1]
for _ in range(20):
    F.append(F[-2] + F[-1])

PP = F[::2]
PP
# Out:
# [1, 2, 5, 13, 34, 89, 233, 610, 1597, 4181, 10946]

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product

# %%
L = [(0,0), (2,1), (2,14),(0,13)]
L.append(L[0])

# %%
plt.axes().set_aspect('equal')

i = 5
a = PP[i]
A = np.array([PP[i-1],1,1,PP[i+1]]).reshape(2,2) 
A2 = np.array([PP[i+1],-1,-1,PP[i-1]]).reshape(2,2) 

X = range(1,PP[i-1]+1) 
Y = range(1,PP[i-1]+1)
Y = range(1,13)
grid = np.array(list(product(X,Y )))
X,Y = grid.T
plt.plot(X,Y,'rx')


t_1 = (PP[i-1]**2 - 1)/(PP[i-1]**2 - 1 + PP[i+1] - PP[i-1])

I = np.linspace(0,t_1,40)
V = np.array([1-I, I])
automorph = np.array([0,1,-1,3*a]).reshape(2,2)
pts = [ ((1-t)*np.identity(2) + t*automorph ) @ A[0] for t in I ]
X,Y = np.array(pts).T

FF = np.sqrt(mm(I,I-1))
X /= FF
Y /= FF

plt.plot(Y,X,'b');

plt.plot(A[0],list(reversed(A[0])),'ko');
plt.plot([0],[0],'ko');

#cc = np.array([[8,16,32],[4,2,1]])
cc = np.array([[34,13,5],[1,2,5]])
#cc = np.array([[89,34,13,a/np.sqrt(3*a - 2)],[1,2,5,a/np.sqrt(3*a - 2)]])
X,Y = cc
plt.plot(X,Y,'k-');
#plt.plot(Y,X,'k-');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 24
#      21 pts = [ ((1-t)*np.identity(2) + t*automorph ) @ A[0] for t in I ]
#      22 X,Y = np.array(pts).T
# ---> 24 FF = np.sqrt(mm(I,I-1))
#      25 X /= FF
#      26 Y /= FF
#
# NameError: name 'mm' is not defined

# %%
def good(n):
    for p in [3,7,11,19,23,31]:
        if n % p == 0: return False
    #if n == 9: return False
    else: return True


plt.axes().set_aspect('equal')

i = 6
a = PP[i]
A = np.array([PP[i-1],1,1,PP[i+1]]).reshape(2,2) 
A2 = np.array([PP[i+1],-1,-1,PP[i-1]]).reshape(2,2) 

X = [_ for _ in range(1,int(nn(1))+1) if good(_)]
#Y = [_ for _ in range(1,PP[i-1]+1) if good(_)]
Y = [_ for _ in range(1,13) if good(_)]
print(Y)
grid = np.array(list(product(X,Y )))
X,Y = grid.T
plt.plot(X,Y,'rx')


t_1 = (PP[i-1]**2 - 1)/(PP[i-1]**2 - 1 + PP[i+1] - PP[i-1])
# modded here to get lower half
I = np.linspace(t_1/2-.3,t_1,40)
V = np.array([1-I, I])
automorph = np.array([0,1,-1,3*a]).reshape(2,2)
pts = [ ((1-t)*np.identity(2) + t*automorph ) @ A[0] for t in I ]
Y,X  = np.array(pts).T


FF = np.sqrt(mm(I,I-1))[:len(X)]
X /= FF
Y /= FF

X = X[X<40]
Y = Y[:len(X)]

plt.plot(X,Y,'b');

plt.plot([5],[5] ,'ko');
plt.plot([0],[0],'ko');


cc = np.array([[89,34,13,5],[1,2,5,13]])
#cc = np.array([[34,21,13,8,5],[1,1,2,3,5]])
#cc = np.array([[89,34,13,a/np.sqrt(3*a - 2)],[1,2,5,a/np.sqrt(3*a - 2)]])
A,B = cc

plt.plot(A,B,'k-');
plt.plot(A,B,'kx');
#plt.plot(Y,X,'k-');
# Out:
# [1, 2, 4, 5, 8, 10]

# %%
a
# Out:
# 233

# %%
mm(34,2)/a**2,
nn(5)
# Out:
# 15.6102084716822

# %%
def good(n):
    for p in [3,7,11,19]:
        if n % p == 0: return False
    else: return True

a = 89

M = np.array([2,1,1,13])

#L = [(0,0), (a,1), (a+1,A+1),(1,A)]
#L.append(L[0])
#X, Y = np.array(L).T
#plt.plot(X,Y)

X = [_ for _ in range(1,int(nn(1))+1) if good(_)]
Y = [_ for _ in range(1,int(nn(1))+1) if good(_)]
grid = np.array(list(product(X,Y )))
plt.axes().set_aspect('equal')


X,Y = grid.T
plt.plot(X,Y,'ro');

t0 = a/np.sqrt(3*a - 2) 


T = np.linspace(t0,34,20)
plt.plot(nn(T),T,'b')
plt.plot(T,nn(T),'b');

plt.plot([8,16,32],[4,2,1],'ko');

# %%
1 + mm(33,1)/ 89**2
# Out:
# 0.025249337204898414

# %%
plt.axes().set_aspect('equal')

X, Y = grid.T
plt.plot(X,Y,'ro');

# %%
def nn(x):
    #sgn  = -1 if x > a else 1    
    sgn = -1
    return .5*( 3*a*x - np.sqrt(9*(a*x)**2  - 4*(a**2 + x**2)))

def mm(x,y):
    return x**2 - 3*a*x*y + y**2

# %%
mm(,1)
# Out:
# -7921

# %%
n = np.array([2,-1,1])

n@(np.array([3,0,3]) - 4/3*n)
# Out:
# 1.0000000000000004

# %%
# Out:
# 57

# %%
import sys
sys.path.append("/home/macbuse/miniconda3/lib/python3.11/site-packages")
import requests
import re

# %%
base_url = "https://www.theguardian.com/"
url = base_url + "uk/commentisfree#maincontent"
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
def fix_art_list():
    with open("art_list.md","r") as fp:
        arts = fp.readlines()
    truncated = [_[len(base_url):] for _ in arts]
    payload = ''.join(truncated)
    with open("art_list_new.md","w") as fp:
        fp.write(payload)

fix_art_list()


pp = re.compile(r'href="(.*?)"')
pp = re.compile(r'"/commentisfree/2026/jan/\d+/.*?"')

L = [_[2:-1] for _ in pp.findall(r.text) if "#comments" not in _]
L = sorted(list(set(L)))
#print('\n'.join([_.split('/')[-1] for _ in L]))
with open("art_list_new.md","r") as fp:
    arts = [_.strip() for _ in fp.readlines()]

#arts = sorted(list(set(arts)))
#payload = '\n'.join(arts)

payload = [_ for _ in L  if _   not in arts ]


print(payload)
if payload:
    with open("art_list_new.md","a") as fp:
        fp.write('\n'.join(payload))
# Out:
# ['commentisfree/2026/jan/25/council-homes-somerset-uk-glorious-proof-labour', 'commentisfree/2026/jan/25/labour-reverse-decision-block-andy-burnham', 'commentisfree/2026/jan/25/the-guardian-view-on-europes-payments-problem-sovereignty-starts-at-the-till', 'commentisfree/2026/jan/25/the-guardian-view-on-the-future-of-cinema-gen-z-is-falling-in-love-with-the-big-screen', 'commentisfree/2026/jan/26/100k-salary-debate-britain', 'commentisfree/2026/jan/26/alex-pretti-minneapolis-shooting', 'commentisfree/2026/jan/26/allies-united-states-old-world-order-dying', 'commentisfree/2026/jan/26/andy-burnham-labour-new-leader', 'commentisfree/2026/jan/26/suella-braverman-reform-conservative-jenrick-kemi-badenoch', 'commentisfree/2026/jan/26/the-guardian-view-on-a-second-ice-killing-in-minneapolis-midnight-in-america-', 'commentisfree/2026/jan/26/the-guardian-view-on-keir-starmers-control-freakery-beating-reform-requires-risking-power', 'commentisfree/2026/jan/26/ukraine-winter-power-freezing-cold-
# ...

# %%
print('\n'.join([f"{base_url}{_}"for _ in payload]))
# Out:
# https://www.theguardian.com/commentisfree/2026/jan/25/council-homes-somerset-uk-glorious-proof-labour
# https://www.theguardian.com/commentisfree/2026/jan/25/labour-reverse-decision-block-andy-burnham
# https://www.theguardian.com/commentisfree/2026/jan/25/the-guardian-view-on-europes-payments-problem-sovereignty-starts-at-the-till
# https://www.theguardian.com/commentisfree/2026/jan/25/the-guardian-view-on-the-future-of-cinema-gen-z-is-falling-in-love-with-the-big-screen
# https://www.theguardian.com/commentisfree/2026/jan/26/100k-salary-debate-britain
# https://www.theguardian.com/commentisfree/2026/jan/26/alex-pretti-minneapolis-shooting
# https://www.theguardian.com/commentisfree/2026/jan/26/allies-united-states-old-world-order-dying
# https://www.theguardian.com/commentisfree/2026/jan/26/andy-burnham-labour-new-leader
# https://www.theguardian.com/commentisfree/2026/jan/26/suella-braverman-reform-conservative-jenrick-kemi-badenoch
# ...

# %% [markdown]
# ---
# ---
#
# https://www.theguardian.com/commentisfree/2026/jan/11/uk-high-streets-reform-shops-closing-hope
# https://www.theguardian.com/commentisfree/2026/jan/12/donald-trump-nigel-farage-london-crime-sadiq-khan
# https://www.theguardian.com/commentisfree/2026/jan/13/crowds-offensive-chants-keir-starmer
# https://www.theguardian.com/commentisfree/2026/jan/14/labour-tories-old-normal-voters
# https://www.theguardian.com/commentisfree/2026/jan/15/iran-protests-survivors-regime-freedom
# https://www.theguardian.com/commentisfree/2026/jan/15/nigel-farage-robert-jenrick-tory-reform-uk
# https://www.theguardian.com/commentisfree/2026/jan/15/rude-new-world-internationalism-trump-greenland
# https://www.theguardian.com/commentisfree/2026/jan/15/state-of-world-today-1980s-2020s-britain-history
# https://www.theguardian.com/commentisfree/2026/jan/16/gaza-west-midlands-police-british-jews-british-muslims-villa-park
# https://www.theguardian.com/commentisfree/2026/jan/16/greenland-us-trump-diplomacy-european-troops
# https://www.theguardian.com/commentisfree/2026/jan/16/nigel-farage-cabinet-tories-robert-jenrick
# https://www.theguardian.com/commentisfree/2026/jan/16/people-of-iran-us-bombs-tehran
# https://www.theguardian.com/commentisfree/2026/jan/16/super-rich-inequality-politicians-extreme-wealth
# https://www.theguardian.com/commentisfree/2026/jan/16/the-guardian-view-on-craig-guildfords-departure-right-decision-dangerous-implications
# https://www.theguardian.com/commentisfree/2026/jan/16/the-guardian-view-on-ice-and-renee-goods-killing-trumpisms-brutal-tactics-dont-end-with-migrants
# https://www.theguardian.com/commentisfree/2026/jan/16/trump-power-right-starmer-potholes
# https://www.theguardian.com/commentisfree/2026/jan/17/a-and-e-broken-wrist-nhs
# https://www.theguardian.com/commentisfree/2026/jan/17/claudette-colvin-collective-resistance-civil-rights-rosa-parks
# https://www.theguardian.com/commentisfree/2026/jan/17/stag-hen-dos-should-be-fun-not-bankrupting
# https://www.theguardian.com/commentisfree/2026/jan/18/iran-democracy-independent-media-civil-society-rule-of-law
# https://www.theguardian.com/commentisfree/2026/jan/18/reform-tory-defections-robert-jenrick
# https://www.theguardian.com/commentisfree/2026/jan/18/the-guardian-view-on-microplastics-research-questioning-results-is-good-for-science-but-has-political-consequences
# https://www.theguardian.com/commentisfree/2026/jan/18/the-guardian-view-on-trump-and-greenland-get-real-bullying-is-not-strength
# https://www.theguardian.com/commentisfree/2026/jan/18/trump-greenland-britain-europe
# https://www.theguardian.com/commentisfree/2026/jan/18/weight-loss-drugs-body-confidence-food-beauty-pharmaceutical-companies-glp-1-drugs
# https://www.theguardian.com/commentisfree/2026/jan/18/why-am-i-a-vegan-i-do-it-for-my-mental-health
# https://www.theguardian.com/commentisfree/2026/jan/19/ice-crackdown-britain
# https://www.theguardian.com/commentisfree/2026/jan/19/trump-kennedy-center-soul

# %%
from goose3 import Goose
import pyperclip 

gg = Goose()

url = "https://www.theguardian.com/commentisfree/2025/nov/24/donald-trump-peace-plan-kremlin-ukraine"
url = "https://www.theguardian.com/commentisfree/2025/nov/29/marriage-women-men-survey-data-girls"
url = "https://www.theguardian.com/commentisfree/2025/nov/24/horror-stories-feminised-workplace-crisis-male-identity-women"
url = "https://www.theguardian.com/commentisfree/2025/nov/30/labour-squeezed-middle-class-budget-families-voters"
url = "https://www.theguardian.com/commentisfree/2025/dec/02/misleading-rachel-reeves-budget-labour-bond-markets"
url = "https://www.theguardian.com/commentisfree/2025/dec/04/europe-trump-putin-plans-ukraine-nato"
url = "https://www.theguardian.com/commentisfree/2025/dec/06/europe-ukraine-putin-trump-eu"
url = "https://www.theguardian.com/commentisfree/2025/dec/10/medical-students-hope-future-nhs"

goose_art = gg.extract(url=url) 
txt = goose_art.cleaned_text
print(txt)


pyperclip.copy(txt)
#print(txt)

pyperclip.paste()
print(txt)
# Out:
# When I mentioned to colleagues in the NHS that I was helping with admissions interviews for medical students, several responded with the same wry smile and weary shrug: “Do they know what they’re getting into?” Anyone working with the health service over the past few decades has seen the job conditions get tougher, salaries stagnate and idealism erode within a crumbling system. Brexit, Covid, austerity and the rise in the cost of living haven’t helped.
#
# From the students’ perspectives, they’ve gone through a lot to get here too. Not just the usual high-level academic performance and résumé-building either. This is a group who dealt with school closures and lockdowns during impressionable years, many come from crowded schools with little support and coaching, and yet they’ve found a way to persevere.
#
# ...

# %%
print(txt)
# Out:
# The failure of this week’s peace talks between Vladimir Putin and Donald Trump’s envoy Steve Witkoff fits into a now well-established pattern of standoffs on Ukraine during Trump’s second term. But the dynamic that produced these talks may be becoming more entrenched. The US and Russian interests driving the process have not changed, while the conflict on the ground is intensifying. The lack of progress this week means there will be another attempt to end the war soon, and perhaps another after that, until, one day, there is some kind of US-backed deal to halt the conflict on terms broadly favouring Russia.
#
# ...

# %%
The failure of this week’s peace talks between Vladimir Putin and Donald Trump’s envoy Steve Witkoff fits into a now well-established pattern of standoffs on Ukraine during Trump’s second term. But the dynamic that produced these talks may be becoming more entrenched. The US and Russian interests driving the process have not changed, while the conflict on the ground is intensifying. The lack of progress this week means there will be another attempt to end the war soon, and perhaps another after that, until, one day, there is some kind of US-backed deal to halt the conflict on terms broadly favouring Russia.\n\nThe geopolitical algorithm driving this effort is too consistent to ignore. It has been repeated ever since Trump re-entered the White House in January. On the campaign trail, Trump had claimed he could stop the war in a day. That was never going to happen. But from 12 February onwards, when Trump first talked directly to Putin about Ukraine, the intention and approach have not altered. There is no reason to suppose they will do so now. Indeed, Tuesday’s impasse may spur them on again.\n\nThe internal logic of the interactions that have brought us to this point is familiar by now. Trump refuses to give arms to Ukraine. Instead he attempts a bilateral deal with Putin to stop the war at Ukraine’s territorial expense. Russia bombs Ukraine and makes attritional battlefield progress. Ukraine and its other allies mobilise to challenge any emerging pro-Russian deal. The US rebalances its plans to take account of the objections. Talks take place. Putin says no deal. The war continues, but so does the diplomacy.\n\nAs this process repeats itself, as it will, one of two things will happen. Either the process will be recognised as achieving nothing, or some aspect of it will be changed to make an outcome more likely. The first option, abandonment of the process, is a possibility, but this would mean humiliation for Trump. It would also mean the war would intensify and become more lethal, destructive and destabilising. Pressures to stop it would thus recur, leading to the resumption of the US diplomatic effort, but from a weaker position than today.\n\nThe second option, the alteration or bypassing of some aspect of the process, therefore seems more likely. This inevitably places Nato and Europe firmly in the crosshairs of Moscow, in particular, and also of Washington. It explains why the Kremlin hinted yesterday that there were still agreements worth making – agreements, in other words, between Russia and the US, from which Europe is excluded. Putin could not be clearer that he sees Europe as Trump’s weak link. “Europe is preventing the US administration from achieving peace on Ukraine,” he said before the talks with Witkoff this week. “They are on the side of war,” he said a little later. “Russia does not intend to fight Europe, but if Europe starts, we are ready right now.”\n\nSome of this is nonsense. But Putin’s key insight is right. Europe – more accurately Nato minus the US – is indeed managing to frustrate Trump from making the kind of deal with Putin that he wants. The Nato allies’ consistent dedication to this task has not been widely celebrated, for fear of provoking Trump, but it is impossible to miss. The effort has been intense, from the moment that Trump and JD Vance publicly abused Volodymyr Zelenskyy during his Oval Office visit on 28 February. It has also been more or less successful.\n\nThis so-called “coalition of the willing” has the power to wound US-Russia plans, but it lacks the power to shape them. The coalition involves most European nations, plus Canada, all of whom have committed to material support for postwar Ukraine. Its aims have been pursued ad hoc, and partly within Nato, as in yesterday’s foreign ministers’ meeting at Nato HQ in Brussels, from which the US secretary of state Marco Rubio was conspicuously absent.\n\nEither way, the European scramble on Ukraine’s behalf has repeatedly managed to hold the line against Trump and Putin. It did so again this week when the Witkoff plan was tweaked before the Putin meeting. Hugging Zelenskyy closer has been a key part of this effort ever since the Oval Office disaster. It would be surprising if Zelenskyy was not being intensively advised and consulted by the allies at almost every turn. I would bet that, if we ever get access to a log of his messages, memos, meetings and travels, we will find that Keir Starmer’s national security adviser, Jonathan Powell, plays a big role in this effort.\n\nYet this cannot and will not continue indefinitely. The central problem for both Ukraine and Europe is that the 21st-century imbalance of power is turned against them. In this new imbalance, Europe and Nato have not enough arms, power or wealth to leverage an alternative peace settlement that Russia and the US are compelled to take seriously or accept. The postwar idea of the west may not be dead, but it is in intensive care. European and some American surgeons are battling with all the skill at their disposal to keep it alive. The truth, though, is that Trump could very easily pull the plug tomorrow.\n\nIf that were to happen, the danger of Russian troops eventually marching down Whitehall might remain remote. But the threat to Kyiv’s main street, Khreshchatyk, would undoubtedly increase. Whether Trump grasps this, or cares, is hard to say. It is not impossible that an effective Ukrainian government, whether headed by Zelenskyy or not, could continue to function and win the financial and military support of international backers to begin reconstruction. Much would depend on whether the west’s frozen Russian assets, worth £253bn, ended up in Kyiv or are returned to Moscow.\n\nEither way, Nato could then prove to be yesterday’s solution to tomorrow’s threat. The Nato nations would all still have their weapons and armed forces. They would retain their commitment to an independent Ukraine and to their common values. They would also continue to possess what the London-based historian Georgios Varouxakis, author of the widely praised The West: The History of an Idea, calls their “capacity for self-criticism and self-correction”. But the strategic self-correction required of Europe in the absence of a fully committed US partner would be arduous, and could involve a price tag that few European nations and voters would be willing to pay.\n\nIt may not be true, yet, that Trump’s US has reached a fateful fork in the road, where it decides to choose between Europe and Ukraine on the one hand, and Russia on the other. But that place and that moment are getting closer than at any time since 1945. The looming tragedy is that history has conferred upon Europe a role in support of Ukraine that it is ultimately unable to fulfil to anything like the degree required.

# %%
# Out:
# Found existing installation: goose3 3.1.20
# Uninstalling goose3-3.1.20:
#   Would remove:
#     /home/macbuse/miniconda3/lib/python3.11/site-packages/goose3-3.1.20.dist-info/*
#     /home/macbuse/miniconda3/lib/python3.11/site-packages/goose3/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %%
! pip install goose3

# %%
pip install pyperclip
# Out:
# /home/macbuse/notebooks/bin/python3: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
Example of Instability,Mechanism,Outcome
The French Model (Populism & Fragmentation),"The rise of populist movements (like the Gilets Jaunes, or ""Yellow Vests"") is strongly linked to regressive consumption taxes (like fuel tax hikes) that disproportionately hurt peripheral, lower-middle-class workers and small business owners. This protest isn't just about the tax, but the feeling that mainstream parties ignore their financial pressure.","Collapse of traditional party support (Socialists and Republicans), leading to political fragmentation and government instability/gridlock."
UK (Historical Example),"The ""Poll Tax"" Riots of the late 1980s and early 1990s were a direct response to a proposed lump-sum tax (a purely regressive tax on every individual, regardless of income) that was perceived as grossly unfair to the poor and working class.","Mass non-compliance, widespread riots, and the eventual downfall of the Prime Minister, Margaret Thatcher."
US & Europe (Rise of Extremes),"Income inequality (driven partly by less progressive tax systems) concentrates political power and resources at the top, leading to political polarization and the hollowing out of the political center. The ""squeezed middle"" shifts its allegiance to parties on the far-left or far-right promising radical change.","Increased government gridlock, a decline in institutional trust, and the rise of nationalist/populist leaders."

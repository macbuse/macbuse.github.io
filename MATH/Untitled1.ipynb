# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

exemple1 = npr.random(10)
exemple2 = npr.choice(exemple1, size=(2,3), replace=False)
exemple3 = npr.choice([0,3,4],10,p=[1/4,1/4,1/2])
x = np.linspace(-3, 3, num=100)
plt.figure()
plt.subplot(2,2,1)
plt.title("Densité")
plt.plot(x, stats.norm(loc=0, scale=1).pdf(x))
plt.xlabel("x")
plt.ylabel("Probabilité")
# Out:
# Text(0, 0.5, 'Probabilité')

# %%
! pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.16.3-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /home/macbuse/miniconda3/envs/newpy/lib/python3.14/site-packages (from scipy) (2.3.5)
# Downloading scipy-1.16.3-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 917.5 kB/s  0:00:38 eta 0:00:010:00:02
# Installing collected packages: scipy
# Successfully installed scipy-1.16.3

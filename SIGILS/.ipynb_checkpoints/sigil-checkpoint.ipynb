# %%
import numpy as np
import matplotlib.pyplot as plt
import string

# %%
ss = "I am very lucky"

# %%
import re
def txt2sig_txt(ss):
    xx = [x for x in re.sub('[aeiouy ,-]','', ss.lower())]
    return list(dict.fromkeys(xx))

sig_chars = txt2sig_txt(ss='I am rich')

# %%
sig_chars
# Out:
# ['m', 'r', 'c', 'h']

# %%
def ring(n=4,r=100):
    T = np.linspace(0,2*np.pi,n+1)
    return r*np.cos(T), r*np.sin(T)

def txt2path(sig_chars):
    def lets2pos():
        pts= []
        rs = [100,70, 30]
        for n in [13, 8, 5]:
            tt = zip(* ring(n=n, r=rs.pop(0))) 
            pts.extend( list(tt)[:-1])
        return dict(zip(string.ascii_lowercase, pts))
    
    pos =  lets2pos()
    return [ np.array(pos[x]) for x in sig_chars]

# %%
txt2path(string.ascii_lowercase)
# Out:
# [array([100.,   0.]),
#  array([88.54560257, 46.4723172 ]),
#  array([56.80647467, 82.29838659]),
#  array([12.05366803, 99.27088741]),
#  array([-35.4604887 ,  93.50162427]),
#  array([-74.85107482,  66.31226582]),
#  array([-97.09418174,  23.93156643]),
#  array([-97.09418174, -23.93156643]),
#  array([-74.85107482, -66.31226582]),
#  array([-35.4604887 , -93.50162427]),
#  array([ 12.05366803, -99.27088741]),
#  array([ 56.80647467, -82.29838659]),
#  array([ 88.54560257, -46.4723172 ]),
#  array([70.,  0.]),
#  array([49.49747468, 49.49747468]),
#  array([4.2862638e-15, 7.0000000e+01]),
#  array([-49.49747468,  49.49747468]),
#  array([-7.00000000e+01,  8.57252759e-15]),
#  array([-49.49747468, -49.49747468]),
#  array([-1.28587914e-14, -7.00000000e+01]),
#  array([ 49.49747468, -49.49747468]),
#  array([30.,  0.]),
#  array([ 9.27050983, 28.53169549]),
#  array([-24.27050983,  17.63355757]),
#  array([-24.27050983, -17.63355757]),
#  array([  9.27050983, -28.53169549])]

# %%
import string

# %%
txt2path(sig_chars)
# Out:
# [(88.54560256532096, -46.472317204376914),
#  (-70.0, 8.572527594031473e-15),
#  (56.806474673115595, 82.29838658936563),
#  (-97.09418174260522, -23.931566428755744)]

# %%
def tan2vec(u):
    x = np.zeros(3)
    x[:2] = u[:2]
    x[2] = u[:2].dot(u[2:])
    return x


u = np.array((0,1,1,0))
v = np.array((1,0,0,1))
np.cross(tan2vec(u), tan2vec(v))
# Out:
# array([ 0.,  0., -1.])

# %%
T = np.linspace(0,2*np.pi,6)
X = np.cos(T)
Y = np.sin(T)

plt.plot(X,Y)

# %%
def ref(x, yy):
    # avoids a square root
    # reflection in the middle
    return x - 2*np.dot(x,yy)*yy/sum(yy*yy)

def t2line(pt,tt):
    x = np.zeros(3)
    x[:2] = tt[:2]
    x[2] = -np.dot(pt,tt)
    return x

t2vec = t2line

def a2b(a,b):
    plt.plot([a[0],b[0]], [a[1],b[1]])
    
def rot(tx = np.radians(30)):
    c, s = np.cos(tx), np.sin(tx)
    return np.array(((c, -s), (s, c)))

    
pts = np.zeros((2,len(X)))
pts[0] = X
pts[1] = Y
pts = pts.transpose()
N = np.array([-1,0])
def ab(a,b):
    plt.plot([a[0],b[0]], [a[1],b[1]])

for a,b in zip(pts[:-1], pts[1:]):
    
    ab(a,a+N)
    xx = np.cross( t2vec((b+a)/2, b-a ) , t2vec(a,N))
    xx = xx / xx[2]
    N = ref(N,a-b)
    R = np.linalg.norm(b - xx[:2])
    print(np.linalg.norm(a - xx[:2]),np.linalg.norm(b - xx[:2]))
    aa, bb = ring(n=20,r=R)
    aa  = aa + xx[0]
    bb = bb + xx[1]
    plt.plot(aa, bb,'r')
# Out:
# 0.19790338987346345 0.19790338987347136
# 0.210114743842163 0.2101147438421542
# 0.23241508783616546 0.2324150878361524
# 0.24742628160742694 0.24742628160742905
# 0.2764280225041924 0.27642802250418547
# 0.2950576525961582 0.2950576525961713
# 0.33358150457977653 0.3335815045797894
# 0.3568893870022967 0.35688938700229667
# 0.40929586007597557 0.4092958600759793
# 0.4385822067876913 0.4385822067876849
# 0.5117861110056275 0.5117861110056217
# 0.5484162153155016 0.548416215315496
# 0.6536204723701026 0.6536204723701022
# 0.6982875782084059 0.6982875782083987
# 0.8538036415810626 0.8538036415810746
# 0.9041457538163523 0.9041457538163532
# 1.139175483985743 1.1391754839857333
# 1.1830455525353412 1.1830455525353443
# 1.5390497374218919 1.5390497374218906
# 1.5387866366651843 1.5387866366651786
# 2.053419023525889 2.0534190235259007
# 1.9240471777407337 1.9240471777407355
# 2.567613806524879 2.5676138065248915
# 2.198946382645943 2.1989463826459343
# 2.8011585831644763 2.801158583164486
# 2.1989463826459144 2.1989463826459144
# 2.567613806524901 2.567613806524884
# 1.9240471777407606 1.9240471777407562
# 2.053419023525906 2.0534190235259007
# 1.5387866366651943 1.5387866366652034
# 1.5390497374219498 1.539049737421949
# 1.1830455525353993 1.1830455525353951
# 1.1391754839857784 1.1391754839857753
# 0.9041457538163545 0.9041457538163546
# 0.8538036415811732 0.8538036415811748
# 0.6982875782084428 0.6982875782084433
# 0.6536204723702027 0.6536204723702016
# 0.5484162153155897 0.5484162153155893
# 0.5117861110057426 0.5117861110057447
# 0.4385822067877971 0.43858220678779464
# 0.40929586007609725 0.4092958600760915
# 0.35688938700239037 0.3568893870023862
# 0.33358150457991276 0.3335815045799104
# 0.2950576525962746 0.29505765259627303
# 0.2764280225043242 0.27642802250432746
# 0.2474262816075061 0.24742628160749663
# 0.23241508783621256 0.23241508783622186
# 0.21011474384219658 0.2101147438421942
# 0.19790338987350425 0.19790338987349865

# %%
fig, ax = plt.subplots(1,1)
ax.set_axis_off() 
ax.set_aspect('equal') 

fig.set_size_inches(10,10)

pts = txt2path(txt2sig_txt('my plans will pull through'))
N = np.array([1,0])

for a, b in zip(pts[:-1], pts[1:]):

    ab(a, a+N)
    xx = np.cross( t2line((b+a)/2, b-a ) , t2line(a,N))
    CC = (xx / xx[2])[:2]
    R = np.linalg.norm(b - CC)
    # bit of a hack linearise and project
    T  = np.linspace(0,1,100)
    aa, bb = [], []
    for t in T:
        dd = (1-t)*a + t*b - CC
        #projection
        dd =  dd * R / np.linalg.norm(dd) + CC
        aa.append(dd[0])
        bb.append(dd[1])
    ax.plot(aa, bb,'r')
    N = ref(N,a-b)
    
rs = [100,70, 30]    
for n in [13, 8, 5]:
    X,Y = ring(n=n, r=rs.pop(0))
    ax.plot(X,Y,'y')

# %% [raw]
# txt2sig_txt('I am very happy')

# %%
def mk_arcs( pts, N=np.array([-1,0])):
    length = np.linalg.norm
    arcs = []
    for a, b in zip(pts[:-1], pts[1:]):

        a2b =  b - a
        mid_pt = (b + a)/2
        xx = np.cross( t2line(mid_pt,a2b) , t2line(a,N))
        CC = (xx / xx[2])[:2]
        R = np.linalg.norm(a - CC)
        #reflect the tangent
        N = N - 2*np.dot(N, a2b)*a2b/sum(a2b*a2b)
        # bit of a hack linearise and project
        # failed if CC was on the segment
        # should maybe just drop the segment
        # tricky broadcasting
        
        threshold = length(b-a)/20
        dist = np.linalg.norm( CC - mid_pt)
   
            
        if dist <  threshold: 
            CC = mid_pt + 1.5*threshold*(CC - mid_pt)/dist
            R = np.linalg.norm(a - CC)
            print(np.linalg.norm( CC - mid_pt), threshold)
            #drop seg
            continue
            
            x, y = CC
            ax.plot([x],[y],'yo')
            M = np.ones((2,2))
            M[0] = a
            M[1] = b
            X,Y = M.transpose()
            ax.plot(X,Y,'g')  
        
        T  = np.linspace(0,1,50) 
            
        arc = T*a.reshape(-1,1) + (1-T)*b.reshape(-1,1)
        CC = CC.reshape(-1,1)
        arc = arc - CC
        dist = np.sqrt( (arc*arc).sum(axis=0)) 
        arcs.append(R*arc/dist + CC)
    return arcs

def show(pts, 
         N=np.array([1,0]),
         ax=plt):
    
    for aa in mk_arcs(pts, N):
        X,Y = aa
        ax.plot(X,Y,'r')

fig, axs = plt.subplots(3,2)
fig.set_size_inches(10,10)
axs = axs.ravel()

NS = np.array([ np.array([1,0]).dot(rot(t))
               for t in np.linspace(0,10,2)])

for ax in axs:
    ax.set_axis_off() 
    ax.set_aspect('equal') 
  
    for n,r  in zip([13, 8, 5],[100,70, 30]):
        X, Y = ring(n=n, r=r)
        ax.plot(X, Y ,'b')

    for NN in NS:
        show(pts,N=NN,ax= ax)
        
    NS = NS.dot(rot(30))
# Out:
# 2.6450336353161297 1.7633557568774194
# 14.890633111470812 9.92708874098054
# 4.986710196264248 3.324473464176164
# 4.98671019626425 3.324473464176164
# 8.620918537481563 5.74727902498771

# %%
def rot(tx=30):
    tx = np.radians(tx)
    c, s = np.cos(tx), np.sin(tx)
    return np.array(((c, -s), (s, c)))

def mk_arc(a,b, N=np.array([-1,0])):
    length = np.linalg.norm
    a2b =  b - a
    mid_pt = (b + a)/2
    xx = np.cross( t2line(mid_pt, a2b) , t2line(a,N))
    CC = (xx / xx[2])[:2]
    R = np.linalg.norm(a - CC) 
            
    T  = np.linspace(0,1,50)     
    arc = T*a.reshape(-1,1) + (1-T)*b.reshape(-1,1)
    CC = CC.reshape(-1,1)
    arc = arc - CC
    dist = np.sqrt( (arc*arc).sum(axis=0)) 
    
    return R*arc/dist + CC

fig, axs = plt.subplots(3,2)
fig.set_size_inches(10,10)
axs = axs.ravel()
for ax in axs:
    ax.set_axis_off() 
    ax.set_aspect('equal') 
    
arcs = []
for ax, s in zip(axs, np.linspace(0,150,6)):
    N = rot(s)[0]
    for a, b in zip(pts[:-1], pts[1:]):
        cols = ['r','y','r']
        for t in np.linspace(0,12,3):
            arcs.append(mk_arc(a,b, N.dot(rot(t))))
            X,Y = arcs[-1]
            ax.plot(X,Y, cols.pop())
        a2b = b - a
        N = N - 2*np.dot(N, a2b)*a2b/sum(a2b*a2b)

# %%
ss = 'I have a wonderful life'
ss = "I feel loved and cared for"
ss = "I catch my connecting flight on time"
ss = "My plans will pull through"
#ss = 'I have a wonderful life'
#this is global
pts = txt2path(txt2sig_txt(ss))
txt2sig_txt(ss)
# Out:
# ['m', 'p', 'l', 'n', 's', 'w', 't', 'h', 'r', 'g']

# %%
np.array(NS).dot(rot).dot(rot)
# Out:
# array([[0.5       , 0.8660254 ],
#        [0.41339746, 0.9160254 ],
#        [0.32679492, 0.9660254 ]])

# %%
pwd
# Out:
# '/home/gregmcshane'

# %%
sss[1]
# Out:
# 'mbsrwlf'

# %%
import pandas as pd

# %%
df = pd.read_excel("./sigils.xlsx", skiprows=2)

# %%
sss[:10]
# Out:
# ['mntbsv',
#  'mbsrwlf',
#  'mfrnxt',
#  'dntpc',
#  'mcl',
#  'mndscl',
#  'wlstrf',
#  'brthdpl',
#  'mnctrl',
#  'blnc']

# %%
sigs = [''.join(txt2sig_txt(x)) for x in phrases]
sss = [x for x in sigs if len(x) < 8]

jj = " ".join(sss)
ww = [jj[i:i+3] for i in range(len(jj)-3)]
ww = [x for x in ww if ' ' not in x]

# %%
from collections import Counter

# %%
ll = Counter(ww)

# %%
ll.most_common()
# Out:
# [('mdv', 24),
#  ('dvt', 24),
#  ('dnt', 23),
#  ('ths', 15),
#  ('mnt', 14),
#  ('cnt', 12),
#  ('ntd', 10),
#  ('mfr', 9),
#  ('mcn', 9),
#  ('sth', 8),
#  ('vth', 8),
#  ('nts', 8),
#  ('mpr', 8),
#  ('fnd', 7),
#  ('thn', 7),
#  ('wth', 7),
#  ('rst', 7),
#  ('ntp', 6),
#  ('wls', 6),
#  ('str', 6),
#  ('mfl', 6),
#  ('ntg', 6),
#  ('trs', 6),
#  ('thr', 6),
#  ('mth', 6),
#  ('ntl', 6),
#  ('mst', 6),
#  ('prs', 6),
#  ('wln', 6),
#  ('msr', 6),
#  ('msc', 6),
#  ('nds', 5),
#  ('dwl', 5),
#  ('tpr', 5),
#  ('prn', 5),
#  ('thg', 5),
#  ('ntf', 5),
#  ('prt', 5),
#  ('vtr', 5),
#  ('ndr', 5),
#  ('ntc', 5),
#  ('ntb', 4),
#  ('mbs', 4),
#  ('scl', 4),
#  ('rth', 4),
#  ('kns', 4),
#  ('rmn', 4),
#  ('hpr', 4),
#  ('gth', 4),
#  ('trn', 4),
#  ('spc', 4),
#  ('cnd', 4),
#  ('prd', 4),
#  ('tfr', 4),
#  ('vtn', 4),
#  ('lng', 4),
#  ('thc', 4),
#  ('dsr', 4),
#  ('nwt', 4),
#  ('fls', 4),
#  ('mgr', 4),
#  ('flw', 4),
#  ('nth', 4),
#  ('tfl', 4),
#  ('rnd', 4),
#  ('tbs', 3),
#  ('mnd', 3),
#  ('mnc', 3),
#  ('ctr', 3),
#  ('trl', 3),
#  ('mkn', 3),
#  ('nst', 3),
#  ('thp', 3),
#  ('hpn', 3),
#  ('hvg', 3),
#  ('vgd', 3),
#  ('mgd', 3),
#  ('gds', 3),
#  ('sfr', 3),
#  ('wlb', 3),
#  ('mrs', 3),
#  ('rsp', 3),
#  ('ndm', 3),
#  ('ndt', 3),
#  ('rls', 3),
#  ('rdn', 3),
#  ('frd', 3),
#  ('spr', 3),
#  ('nsp', 3),
#  ('cnf', 3),
#  ('nfd', 3),
#  ('nsc', 3),
#  ('tds', 3),
#  ('vtp', 3),
#  ('tms', 3),
#  ('vts', 3),
#  ('drs', 3),
#  ('thl', 3),
#  ('tns', 3),
#  ('hrs', 3),
#  ('tls', 3),
#  ('trg', 3),
#  ('tdh', 3),
#  ('mnw', 3),
#  ('lsp', 3),
#  ('rmb', 3),
#  ('stm', 3),
#  ('grd', 3),
#  ('rch', 3),
#  ('rnt', 3),
#  ('tnd', 3),
#  ('snm', 3),
#  ('lsr', 3),
#  ('srv', 3),
#  ('nfl', 3),
#  ('rds', 3),
#  ('srb', 3),
#  ('cln', 3),
#  ('mns', 3),
#  ('ntr', 3),
#  ('ngh', 3),
#  ('rsn', 3),
#  ('snt', 3),
#  ('tsc', 3),
#  ('stc', 3),
#  ('chs', 3),
#  ('grt', 3),
#  ('hns', 3),
#  ('msf', 3),
#  ('mtr', 3),
#  ('trc', 3),
#  ('lnm', 3),
#  ('bsv', 2),
#  ('lst', 2),
#  ('trf', 2),
#  ('brt', 2),
#  ('thd', 2),
#  ('dpl', 2),
#  ('nct', 2),
#  ('bln', 2),
#  ('lnc', 2),
#  ('lnr', 2),
#  ('nsl', 2),
#  ('gtp', 2),
#  ('prm', 2),
#  ('gtr', 2),
#  ('mts', 2),
#  ('tsh', 2),
#  ('pnw', 2),
#  ('nwr', 2),
#  ('gdt', 2),
#  ('rsm', 2),
#  ('smn', 2),
#  ('tvd', 2),
#  ('dtr', 2),
#  ('sft', 2),
#  ('rvl', 2),
#  ('trm', 2),
#  ('rvt', 2),
#  ('dsf', 2),
#  ('gdm', 2),
#  ('dmr', 2),
#  ('pct', 2),
#  ('ctd', 2),
#  ('lrn', 2),
#  ('rnc', 2),
#  ('mlf', 2),
#  ('ndp', 2),
#  ('wlh', 2),
#  ('flc', 2),
#  ('dth', 2),
#  ('frl', 2),
#  ('rmf', 2),
#  ('tcr', 2),
#  ('rfl', 2),
#  ('brv', 2),
#  ('ncs', 2),
#  ('cns', 2),
#  ('lvm', 2),
#  ('fck', 2),
#  ('dfh', 2),
#  ('tdr', 2),
#  ('ngd', 2),
#  ('dsm', 2),
#  ('gwl', 2),
#  ('svr', 2),
#  ('rwh', 2),
#  ('tzl', 2),
#  ('tpl', 2),
#  ('stn', 2),
#  ('tsk', 2),
#  ('tsl', 2),
#  ('sln', 2),
#  ('nrs', 2),
#  ('dns', 2),
#  ('prc', 2),
#  ('tsf', 2),
#  ('sfm', 2),
#  ('lsn', 2),
#  ('mct', 2),
#  ('ctn', 2),
#  ('tps', 2),
#  ('drk', 2),
#  ('nml', 2),
#  ('pts', 2),
#  ('tsd', 2),
#  ('hsl', 2),
#  ('srn', 2),
#  ('mnf', 2),
#  ('lws', 2),
#  ('wst', 2),
#  ('lnt', 2),
#  ('tmb', 2),
#  ('rpl', 2),
#  ('lmg', 2),
#  ('rnm', 2),
#  ('hdr', 2),
#  ('prl', 2),
#  ('frc', 2),
#  ('rcn', 2),
#  ('ntm', 2),
#  ('scr', 2),
#  ('tgp', 2),
#  ('gpr', 2),
#  ('rtl', 2),
#  ('frg', 2),
#  ('frp', 2),
#  ('rpn', 2),
#  ('chn', 2),
#  ('dst', 2),
#  ('btf', 2),
#  ('mng', 2),
#  ('ngm', 2),
#  ('rms', 2),
#  ('nsb', 2),
#  ('rnw', 2),
#  ('nwd', 2),
#  ('cld', 2),
#  ('wht', 2),
#  ('tch', 2),
#  ('nch', 2),
#  ('drm', 2),
#  ('hvm', 2),
#  ('ghr', 2),
#  ('mbl', 2),
#  ('mds', 2),
#  ('mrl', 2),
#  ('thm', 2),
#  ('nmw', 2),
#  ('rsf', 2),
#  ('ptn', 2),
#  ('fcs', 2),
#  ('srt', 2),
#  ('bls', 2),
#  ('tcd', 2),
#  ('dnc', 2),
#  ('tgr', 2),
#  ('rtc', 2),
#  ('tcn', 2),
#  ('dcl', 2),
#  ('clt', 2),
#  ('ltr', 2),
#  ('kpm', 2),
#  ('stl', 2),
#  ('trh', 2),
#  ('hcn', 2),
#  ('sfn', 2),
#  ('hsf', 2),
#  ('hsg', 2),
#  ('mnl', 2),
#  ('swt', 2),
#  ('mhp', 2),
#  ('pns', 2),
#  ('xcl', 2),
#  ('scd', 2),
#  ('slf', 2),
#  ('pwr', 2),
#  ('nld', 2),
#  ('rtf', 2),
#  ('lsf', 2),
#  ('mdc', 2),
#  ('bsr', 1),
#  ('srw', 1),
#  ('rwl', 1),
#  ('wlf', 1),
#  ('frn', 1),
#  ('rnx', 1),
#  ('nxt', 1),
#  ('tpc', 1),
#  ('mcl', 1),
#  ('dsc', 1),
#  ('hdp', 1),
#  ('fln', 1),
#  ('nrp', 1),
#  ('rpc', 1),
#  ('stw', 1),
#  ('twr', 1),
#  ('tgf', 1),
#  ('gfr', 1),
#  ('mtp', 1),
#  ('tpd', 1),
#  ('pdw', 1),
#  ('shp', 1),
#  ('dtn', 1),
#  ('rnl', 1),
#  ('wlg', 1),
#  ('lgh', 1),
#  ('ghm', 1),
#  ('hms', 1),
#  ('msn', 1),
#  ('mtv', 1),
#  ('vdw', 1),
#  ('dwr', 1),
#  ('wrk', 1),
#  ('mdt', 1),
#  ('ftr', 1),
#  ('trv', 1),
#  ('wgt', 1),
#  ('hgn', 1),
#  ('gnm', 1),
#  ('frv', 1),
#  ('lbg', 1),
#  ('bgd', 1),
#  ('tsg', 1),
#  ('sgd', 1),
#  ('gdr', 1),
#  ('msx', 1),
#  ('sxl', 1),
#  ('xlt', 1),
#  ('ltv', 1),
#  ('pls', 1),
#  ('lsm', 1),
#  ('plr', 1),
#  ('ncm', 1),
#  ('cmt', 1),
#  ('dmp', 1),
#  ('mps', 1),
#  ('psg', 1),
#  ('lfs', 1),
#  ('fsp', 1),
#  ('spn', 1),
#  ('dpt', 1),
#  ('ptv', 1),
#  ('lhv', 1),
#  ('hvs', 1),
#  ('vsp', 1),
#  ('lcn', 1),
#  ('dnf', 1),
#  ('cnq', 1),
#  ('nqr', 1),
#  ('qrm', 1),
#  ('mfs', 1),
#  ('hvt', 1),
#  ('vtc', 1),
#  ('crg', 1),
#  ('rgl', 1),
#  ('mvr', 1),
#  ('vrf', 1),
#  ('thq', 1),
#  ('hqn', 1),
#  ('slv', 1),
#  ('vmw', 1),
#  ('ckr', 1),
#  ('krl', 1),
#  ('gnt', 1),
#  ('tdf', 1),
#  ('fhr', 1),
#  ('vlt', 1),
#  ('ltn', 1),
#  ('rtn', 1),
#  ('rfh', 1),
#  ('fhn', 1),
#  ('fdt', 1),
#  ('mrt', 1),
#  ('rtw', 1),
#  ('twn', 1),
#  ('wns', 1),
#  ('nbs', 1),
#  ('tph', 1),
#  ('phr', 1),
#  ('rtm', 1),
#  ('tsr', 1),
#  ('zrl', 1),
#  ('vtb', 1),
#  ('brg', 1),
#  ('rgd', 1),
#  ('cth', 1),
#  ('lhm', 1),
#  ('htr', 1),
#  ('hkt', 1),
#  ('thk', 1),
#  ('hst', 1),
#  ('tnr', 1),
#  ('knr', 1),
#  ('nrt', 1),
#  ('lsv', 1),
#  ('vrw', 1),
#  ('vtl', 1),
#  ('mtz', 1),
#  ('nmr', 1),
#  ('mrg', 1),
#  ('rgn', 1),
#  ('dhs', 1),
#  ('tdx', 1),
#  ('plx', 1),
#  ('pck', 1),
#  ('qtz', 1),
#  ('zlc', 1),
#  ('hls', 1),
#  ('skh', 1),
#  ('tzc', 1),
#  ('zcl', 1),
#  ('clp', 1),
#  ('dhr', 1),
#  ('wpt', 1),
#  ('ptg', 1),
#  ('tgd', 1),
#  ('vtw', 1),
#  ('twp', 1),
#  ('tpn', 1),
#  ('pnl', 1),
#  ('tnh', 1),
#  ('nhr', 1),
#  ('spq', 1),
#  ('pqc', 1),
#  ('qck', 1),
#  ('mbd', 1),
#  ('bds', 1),
#  ('dcn', 1),
#  ('cnr', 1),
#  ('chb', 1),
#  ('hbl', 1),
#  ('fmh', 1),
#  ('snc', 1),
#  ('drb', 1),
#  ('psn', 1),
#  ('rkt', 1),
#  ('kts', 1),
#  ('hsn', 1),
#  ('mld', 1),
#  ('lcp', 1),
#  ('cpt', 1),
#  ('cng', 1),
#  ('ngt', 1),
#  ('wlp', 1),
#  ('lpr', 1),
#  ('rsv', 1),
#  ('rvm', 1),
#  ('vmf', 1),
#  ('slp', 1),
#  ('mwl', 1),
#  ('mnb', 1),
#  ('nbr', 1),
#  ('brk', 1),
#  ('rkl', 1),
#  ('gdl', 1),
#  ('dlc', 1),
#  ('lck', 1),
#  ('mws', 1),
#  ('wsh', 1),
#  ('shc', 1),
#  ('hct', 1),
#  ('dsg', 1),
#  ('lsw', 1),
#  ('gtm', 1),
#  ('wnt', 1),
#  ('tbg', 1),
#  ('plm', 1),
#  ('mgt', 1),
#  ('psk', 1),
#  ('rtg', 1),
#  ('xpc', 1),
#  ('msk', 1),
#  ('skn', 1),
#  ('knp', 1),
#  ('npr', 1),
#  ('tgs', 1),
#  ('srg', 1),
#  ('rgw', 1),
#  ('frt', 1),
#  ('hcs', 1),
#  ('csn', 1),
#  ('snp', 1),
#  ('hgf', 1),
#  ('hgl', 1),
#  ('gln', 1),
#  ('ntv', 1),
#  ('tvr', 1),
#  ('mbn', 1),
#  ('bns', 1),
#  ('nsd', 1),
#  ('sdp', 1),
#  ('hnp', 1),
#  ('rsl', 1),
#  ('rbt', 1),
#  ('hgc', 1),
#  ('gcm', 1),
#  ('crn', 1),
#  ('gdh', 1),
#  ('dhl', 1),
#  ('hlt', 1),
#  ('stp', 1),
#  ('pln', 1),
#  ('mln', 1),
#  ('spt', 1),
#  ('mph', 1),
#  ('pht', 1),
#  ('htg', 1),
#  ('tgn', 1),
#  ('gnc', 1),
#  ('btr', 1),
#  ('trd', 1),
#  ('mbt', 1),
#  ('hcl', 1),
#  ('clb', 1),
#  ('lbf', 1),
#  ('dpr', 1),
#  ('tlh', 1),
#  ('lhn', 1),
#  ('hnm', 1),
#  ('prf', 1),
#  ('rfm', 1),
#  ('fmn', 1),
#  ('ndg', 1),
#  ('dgs', 1),
#  ('cgh', 1),
#  ('ghd', 1),
#  ('drp', 1),
#  ('tgc', 1),
#  ('lbc', 1),
#  ('bcr', 1),
#  ('crd', 1),
#  ('bsp', 1),
#  ('prk', 1),
#  ('frw', 1),
#  ('rwt', 1),
#  ('wts', 1),
#  ('srp', 1),
#  ('pnt', 1),
#  ('scf', 1),
#  ('cfl', 1),
#  ('lwn', 1),
#  ('mkt', 1),
#  ('ktd', 1),
#  ('tdv', 1),
#  ('dvr', 1),
#  ('mrn', 1),
#  ('grn', 1),
#  ('snr', 1),
#  ('nrg', 1),
#  ('rgc', 1),
#  ('gcl', 1),
#  ('rlm', 1),
#  ('dmc', 1),
#  ('cts', 1),
#  ('ght', 1),
#  ('frs', 1),
#  ('wtr', 1),
#  ('cpr', 1),
#  ('gld', 1),
#  ('rkn', 1),
#  ('crw', 1),
#  ('wtc', 1),
#  ('chr', 1),
#  ('hrf', 1),
#  ('chl', 1),
#  ('hld', 1),
#  ('clm', 1),
#  ('csp', 1),
#  ('hsd', 1),
#  ('hlg', 1),
#  ('tmc', 1),
#  ('flr', 1),
#  ('msp', 1),
#  ('vms', 1),
#  ('trw', 1),
#  ('mdp', 1),
#  ('dps', 1),
#  ('psl', 1),
#  ('mtg', 1),
#  ('tgh', 1),
#  ('mpt', 1),
#  ('sdn', 1),
#  ('dng', 1),
#  ('blt', 1),
#  ('ltg', 1),
#  ('rnf', 1),
#  ('flg', 1),
#  ('lsh', 1),
#  ('dsn', 1),
#  ('lbt', 1),
#  ('btm', 1),
#  ('tmn', 1),
#  ('dsp', 1),
#  ('sph', 1),
#  ('rgv', 1),
#  ('gvt', 1),
#  ('mwd', 1),
#  ('sfl', 1),
#  ('wrn', 1),
#  ('rns', 1),
#  ('mbp', 1),
#  ('bpt', 1),
#  ('tnf', 1),
#  ('nfc', 1),
#  ('csd', 1),
#  ('mfc', 1),
#  ('csh', 1),
#  ('shr', 1),
#  ('hrp', 1),
#  ('vmr', 1),
#  ('mrc', 1),
#  ('rcs', 1),
#  ('cst', 1),
#  ('lsd', 1),
#  ('shv', 1),
#  ('hvr', 1),
#  ('vnd', 1),
#  ('hnr', 1),
#  ('nrm', 1),
#  ('mfg', 1),
#  ('fgv', 1),
#  ('hr’', 1),
#  ('r’s', 1),
#  ('snw', 1),
#  ('wdr', 1),
#  ('drh', 1),
#  ('rlz', 1),
#  ('lzm', 1),
#  ('zms', 1),
#  ('stk', 1),
#  ('gvf', 1),
#  ('vfd', 1),
#  ('fdb', 1),
#  ('trp', 1),
#  ('rps', 1),
#  ('thv', 1),
#  ('hvl', 1),
#  ('vlf', 1),
#  ('hsp', 1),
#  ('hnw', 1),
#  ('lbr', 1),
#  ('pms', 1),
#  ('sct', 1),
#  ('hsc', 1),
#  ('fgr', 1),
#  ('jst', 1),
#  ('tcf', 1),
#  ('cfn', 1),
#  ('tln', 1),
#  ('lnd', 1),
#  ('sng', 1),
#  ('ngf', 1),
#  ('gfk', 1),
#  ('hnv', 1),
#  ('nvr', 1),
#  ('vrs', 1),
#  ('rsc', 1),
#  ('hrn', 1),
#  ('ncl', 1),
#  ('rhv', 1),
#  ('hvb', 1),
#  ('brd', 1),
#  ('rdm', 1),
#  ('dmg', 1),
#  ('mgn', 1),
#  ('lvn', 1),
#  ('vnp', 1),
#  ('npc', 1),
#  ('vdr', 1),
#  ('msw', 1),
#  ('swh', 1),
#  ('ftp', 1),
#  ('nlv', 1),
#  ('vmt', 1),
#  ('pld', 1),
#  ('ldn', 1),
#  ('tcm', 1),
#  ('mhd', 1),
#  ('hdn', 1),
#  ('fdm', 1),
#  ('ndc', 1),
#  ('frm', 1),
#  ('rmc', 1),
#  ('rpd', 1),
#  ('sfp', 1),
#  ('fpd', 1),
#  ('knw', 1),
#  ('wrp', 1),
#  ('plc', 1),
#  ('sgr', 1),
#  ('hpm', 1),
#  ('hgs', 1),
#  ('gsc', 1),
#  ('scp', 1),
#  ('mdn', 1),
#  ('nsr', 1),
#  ('rbh', 1),
#  ('hsm', 1),
#  ('rsd', 1),
#  ('sdf', 1),
#  ('ndl', 1),
#  ('dlv', 1),
#  ('mtb', 1),
#  ('tbh', 1),
#  ('bhc', 1),
#  ('frj', 1),
#  ('rjl', 1),
#  ('jls', 1),
#  ('wlr', 1),
#  ('lrg', 1),
#  ('rgs', 1),
#  ('gsm', 1),
#  ('mwt', 1),
#  ('hnf', 1),
#  ('rcv', 1),
#  ('rbl', 1),
#  ('ksb', 1),
#  ('sbl', 1),
#  ('wcn', 1),
#  ('tbr', 1),
#  ('mtl', 1),
#  ('tld', 1),
#  ('ldv', 1),
#  ('mlv', 1),
#  ('lvs', 1),
#  ('vsw', 1),
#  ('smp', 1),
#  ('mpn', 1),
#  ('mft', 1),
#  ('fth', 1),
#  ('nmx', 1),
#  ('mxs', 1),
#  ('nmp', 1),
#  ('mpx', 1),
#  ('mwk', 1),
#  ('gtn', 1),
#  ('nmt', 1),
#  ('ltp', 1),
#  ('psh', 1),
#  ('lns', 1),
#  ('srx', 1),
#  ('rxt', 1),
#  ('xtd', 1),
#  ('tdn', 1),
#  ('cdl', 1),
#  ('cdn', 1),
#  ('bst', 1),
#  ('tlf', 1),
#  ('gdn', 1),
#  ('dnh', 1),
#  ('mkw', 1),
#  ('kwt', 1),
#  ('thb', 1),
#  ('hbd', 1),
#  ('mwr', 1),
#  ('tlv', 1),
#  ('lfd', 1),
#  ('mtn', 1),
#  ('spw', 1),
#  ('ldt', 1),
#  ('dts', 1),
#  ('nwc', 1),
#  ('flk', 1),
#  ('lkm', 1),
#  ('kms', 1),
#  ('wsd', 1),
#  ('rlb', 1),
#  ('mpw', 1),
#  ('wrf', 1),
#  ('mls', 1),
#  ('sfh', 1),
#  ('tcl', 1),
#  ('clg', 1),
#  ('dcs', 1),
#  ('csv', 1),
#  ('pmt', 1),
#  ('hvp', 1),
#  ('vpt', 1),
#  ('tnc', 1),
#  ('wtn', 1),
#  ('ndf', 1),
#  ('gmt', 1),
#  ('mtc', 1),
#  ('wlk', 1),
#  ('lkn', 1),
#  ('knd', 1),
#  ('tdg', 1),
#  ('dgr', 1),
#  ('grh', 1),
#  ('mvc', 1),
#  ('vcd', 1),
#  ('cdp', 1),
#  ('dpn', 1),
#  ('mrw', 1),
#  ('hts', 1),
#  ('plt', 1),
#  ('lth', 1),
#  ('thf', 1),
#  ('hfw', 1),
#  ('fws', 1),
#  ('tfn', 1),
#  ('fnc', 1),
#  ('ndw', 1),
#  ('rpf', 1),
#  ('pfc', 1),
#  ('fct', 1),
#  ('ctl', 1),
#  ('ncw', 1),
#  ('cwl', 1),
#  ('mhn', 1),
#  ('hnd', 1),
#  ('scn', 1),
#  ('cnl', 1),
#  ('fds', 1),
#  ('stg', 1),
#  ('grf', 1),
#  ('dcr', 1),
#  ('crl', 1),
#  ('rlw', 1),
#  ('mxb', 1),
#  ('xbs', 1),
#  ('bsf', 1),
#  ('dtb', 1),
#  ('tbl', 1)]

# %%
ll.most_common()[:20]
# Out:
# [('mdv', 24),
#  ('dvt', 24),
#  ('dnt', 23),
#  ('ths', 15),
#  ('mnt', 14),
#  ('cnt', 12),
#  ('ntd', 10),
#  ('mfr', 9),
#  ('mcn', 9),
#  ('sth', 8),
#  ('vth', 8),
#  ('nts', 8),
#  ('mpr', 8),
#  ('fnd', 7),
#  ('thn', 7),
#  ('wth', 7),
#  ('rst', 7),
#  ('ntp', 6),
#  ('wls', 6),
#  ('str', 6)]

# %%
for x,y in hashed:
    if 'wth' not in x: continue
    print(y)
# Out:
# I deal with customer bullshit calmly and easily
# I drive skillfully and with awareness
# I deal with difficult situations easily and successfully
# Dionysus is always with me
# I am aligned with Ganesha
# Voden is with me
# Yarbog is with me
# I am one with the hunt
# I am responsible with the baby, it is safe in my care
# My plans will pull through
# I move easily and without pain
# My pineal gland opens quickly and with ease
# My period comes without cramps
# I am one with the Force, it flows through me
# I see and feel my soulbonds with ease
# My soulbonds and I become co-conscious with ease
# I am one with the sun, moon, and sea
# I am one with the darkness
# I am one with the light
# My aura and soul are one with the wind
# I bond with my tarot deck
# I memorize my lines with ease
# I am filled with light
# I clean without panicking
# Fuck off (made with Desert Runes alphabet)
# I am with my Twin Flame
# I am dealing with my break up well
# My love is with you
# I keep up with all my classes without my mental problems getting in the way
# I pass my classes with top marks
# I keep up with my classwork
# I pass ENEM with enough pontuation for the university I want
# I learn languages with ease and remember my vocabulary
# I am lucky with multiple choice
# I am okay with my body
# I sing with technical accuracy and emotional beauty
# I run with ease
# I move with grace

# %%
hashed = [(''.join(txt2sig_txt(x)),x) for x in phrases]

# %%
data = ' '.join(phrases).lower()

# %%
stop = '''with will have from this does what through 
when into without while they
over that time need than their'''

voc = [ x for x in txt.split() 
       if len(x) > 3 and x not in stop]
pp = Counter(voc)

# %%
pp.most_common()[:100]
# Out:
# [('strong', 61),
#  ('free', 47),
#  ('safe', 44),
#  ('protected', 42),
#  ('love', 40),
#  ('find', 38),
#  ('good', 36),
#  ('well', 35),
#  ('life', 35),
#  ('relationship', 35),
#  ('ease', 33),
#  ('easily', 32),
#  ('quickly', 30),
#  ('devoted', 29),
#  ('others', 28),
#  ('healthy', 26),
#  ('myself', 25),
#  ('work', 24),
#  ('energy', 23),
#  ('happy', 23),
#  ('family', 22),
#  ('make', 21),
#  ('control', 19),
#  ('people', 19),
#  ('connected', 19),
#  ('body', 19),
#  ('communicate', 18),
#  ('feel', 18),
#  ('place', 17),
#  ('harm', 16),
#  ('home', 16),
#  ('remember', 15),
#  ('spirits', 15),
#  ('always', 14),
#  ('friends', 14),
#  ('past', 13),
#  ('want', 13),
#  ('full', 13),
#  ('peace', 13),
#  ('more', 13),
#  ('dreams', 12),
#  ('negative', 12),
#  ('remain', 12),
#  ('better', 12),
#  ('appear', 12),
#  ('luck', 12),
#  ('courage', 12),
#  ('pain', 12),
#  ('loved', 12),
#  ('know', 11),
#  ('calm', 11),
#  ('stay', 11),
#  ('soon', 11),
#  ('perfect', 11),
#  ('clear', 11),
#  ('year', 11),
#  ('every', 11),
#  ('things', 11),
#  ('confident', 11),
#  ('understand', 11),
#  ('energies', 11),
#  ('person', 10),
#  ('anxiety', 10),
#  ('emotions', 10),
#  ('accepted', 10),
#  ('house', 10),
#  ('relationships', 10),
#  ('keep', 10),
#  ('stop', 10),
#  ('ones', 10),
#  ('hurt', 9),
#  ('positive', 9),
#  ('great', 9),
#  ('help', 9),
#  ('play', 9),
#  ('long', 9),
#  ('pass', 9),
#  ('beautiful', 9),
#  ('flows', 9),
#  ('only', 9),
#  ('hair', 9),
#  ('about', 8),
#  ('self', 8),
#  ('become', 8),
#  ('success', 8),
#  ('attract', 8),
#  ('receive', 8),
#  ('confidence', 8),
#  ('spirit', 8),
#  ('alone', 8),
#  ('enough', 8),
#  ('present', 8),
#  ('skin', 8),
#  ('under', 8),
#  ('urge', 8),
#  ('here', 8),
#  ('magick', 8),
#  ('other', 8),
#  ('school', 8),
#  ('heal', 7)]

# %%
' '.join([x for x,y in pp.most_common()[20:80] ])
# Out:
# 'family make control people connected body communicate feel place harm home remember spirits always friends past want full peace more dreams negative remain better appear luck courage pain loved know calm stay soon perfect clear year every things confident understand energies person anxiety emotions accepted house relationships keep stop their ones hurt positive great help play long pass beautiful flows'

# %%
'with will have from this does what through  when'
# Out:
# 'with will have from this strong free safe protected love find good well life relationship ease easily quickly devoted others'

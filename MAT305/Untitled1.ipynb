# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(-2,2)
Y = -2*X + 3

plt.plot(X,Y,'r')
plt.plot(0*X,Y,'k')
plt.plot(X,0*Y + 3,'b')
plt.plot(X,0*Y,'k');

# %%
X1 = np.linspace(-4,0,100)
X = X1[ X1 + 2 > .1]

Y = 1 + 1/(X1 + 2)

plt.plot(X1,Y,'r')

# %%
x,y  = 5,10
f"{x} {y}"
# Out:
# '5 10'

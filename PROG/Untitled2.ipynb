# %%
import numpy as np
import matplotlib.pyplot as plt

import random

from scipy import signal


import  matplotlib.animation

from matplotlib import animation

from IPython.display import HTML
def plot_images(img_list, fr=100):
    
  def init():
    img.set_data(img_list[0])
    return (img,)

  def animate(i):
    img.set_data(img_list[i])
    return (img,)

  fig = plt.figure()
  ax = fig.gca()
  plt.axis('off')
  img = ax.imshow(img_list[0])

  anim = animation.FuncAnimation(fig,
                                 animate, 
                                 init_func=init,
                                 frames=len(img_list), 
                                 interval=fr, 
                                 blit=True)
  return anim

# use like this
#HTML(plot_images(imgs).to_html5_video())

# %%
sz = 10

S = np.zeros((sz+1,sz+1),dtype=int)
S[:,0] = 1
S[0,:] += 2
S[sz,:] += 4
S[:,sz] += 7


diffs = [[1,0],[0,1],[-1,0],[0,-1]]

nogo = {0: [], 
        1: [3], 2: [2], 7: [1], 4: [0],
        5: [0,3], 9: [1,2],
        3: [2,3], 11:[0,1]
}

moves = {x:  [ y for k,y in enumerate(diffs) if k not in  nogo[x]] for x in nogo}

G = np.zeros((sz+1,sz+1))

pts = [ np.array([k,k],dtype=int) for k in range(2,sz,2)]
             
frames = []
for _ in range(200):
    G = np.zeros((sz+1,sz+1))
    for pt in pts:
        G[tuple(pt)] = 1
        #print(tuple(pts),S[tuple(pts)])
    
        pt += random.choice(moves[S[tuple(pt)]])
    
    frames.append(np.copy(G))

HTML(plot_images(frames, fr=100).to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#makegrid
sz = 10
W = np.zeros((sz+1,sz+1),dtype=int)

#place the walls
W[:,0] = W[0,:] = W[sz,:] = W[:,sz] = 1

# make a kernel
K = [0,1,0,2,0,8,0,4,0]
K = np.array(K).reshape(3,3)

#these are the forbidden transitions for the states
no_go = {0: [], 
        8: [3], 4: [2], 2: [1], 1: [0],
        9: [0,3], 6: [1,2],
        12: [2,3], 3:[0,1]
}


# calculate the states for the grid
X = signal.convolve2d( W, K)[2:-2,2:-2]

diffs = [[1,0,0],[0,1,0],[-1,0,0],[0,-1,0]]
#apparently these get cast to np.array when I add???
allowed_moves = {x:  [ y for k,y in enumerate(diffs) 
                          if k not in  no_go[x]] for x in no_go}

G = np.zeros((sz+1,sz+1)) + 6
#initial configuration
pts = [ np.array([k, k, k%2],dtype=int) for k in range(2, sz, 2)]
             
frames = []
for _ in range(100):
    G = np.zeros((sz+1,sz+1)) + 5
    for pt in pts:
        dd = tuple(pt[:2])
        G[dd] = pt[2]
        pt += random.choice(allowed_moves[X[dd]])
    
    frames.append(np.copy(G))

HTML(plot_images(frames, fr=100).to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
import scipy 

Z = scipy.spatial.distance_matrix(pts, pts, p=np.infty)
vv = np.where(Z < 2.1)

list(zip(vv[0],vv[1])),Z
# Out:
# ([(0, 0), (1, 1), (1, 3), (2, 2), (3, 1), (3, 3)],
#  array([[0., 4., 4., 5.],
#         [4., 0., 4., 1.],
#         [4., 4., 0., 3.],
#         [5., 1., 3., 0.]]))

# %%
nogo = {0: [], 
        4: [3], 8: [2], 2: [1], 1: [0],
        5: [0,3], 10: [1,2],
        12: [2,3], 3:[0,1]
}

# %%
X
# Out:
# array([[12,  4,  4,  6],
#        [ 8,  0,  0,  2],
#        [ 8,  0,  0,  2],
#        [ 9,  1,  1,  3]])

# %%
nogo = {0: [], 
        4: [3], 8: [2], 2: [1], 1: [0],
}

# %%
np.infty
# Out:
# inf

# %%
# Out:
# dict_keys([0, 4, 8, 2, 1])

# %%
K
# Out:
# array([[0, 1, 0],
#        [2, 0, 4],
#        [0, 8, 0]])

MIN4 
Jamais	
Active   
	Avatar Quoc Bao TranQuoc Bao Tran	Quoc-Bao.Tran@etu.univ-grenoble-alpes.fr	
Étudiant 
MIN4 
1 jour 16 heures	
Active   
	Avatar Richard SelvaradjouRichard Selvaradjou	Richard.Selvaradjou@etu.univ-grenoble-alpes.fr	
Étudiant 
MIN4 
2 jours 17 heures	
Active   
	Avatar Ryan RouibahRyan Rouibah	Ryan.Rouibah@etu.univ-grenoble-alpes.fr	
Étudiant 
MIN4 
30 jours 2 heures	
Active   
	Avatar Soidrine SaindouSoidrine Saindou	Soidrine.Saindou@etu.univ-grenoble-alpes.fr	
Étudiant 
MIN4 
2 jours 20 heures	
Active   
	Avatar Thibault RocheThibault Roche	Thibault.Roche@etu.univ-grenoble-alpes.fr	
Étudiant 
MIN4 
Jamais	
Active   
	Avatar Tom ClémentTom Clément	Tom.Clement@etu.univ-grenoble-alpes.fr	
Étudiant 
MIN4 
20 heures 55 min	
Active   
	Avatar Xinyun LiXinyun Li	Xinyun.Li@etu.univ-grenoble-alpes.fr	
Étudiant 
MIN4 
2 jours 14 heures	
Active   
	Avatar Yuhao YangYuhao Yang	Yuhao.Yang@etu.univ-grenoble-alpes.fr'''

# %%
import re

# %%
pp = re.compile('\t(.*?)@')

# %%
ss = ss.replace('\n\t','\n')

names = [ '{} {}'.format(y,x) for x,y in [t.split('.') for t in pp.findall(ss)]]
names.sort()
names
# Out:
# ['Bensbia Hugo',
#  'Clement Tom',
#  'Lambert Mathis',
#  'Lanneau Erwan',
#  'Li Xinyun',
#  'Macaire Florent',
#  'Miserey Paul',
#  'Oke-Codjo Houenangnon',
#  'Paris Guillaume',
#  'Pendeliau Iman',
#  'Pham Quan',
#  'Roche Thibault',
#  'Romain Noe',
#  'Rouibah Ryan',
#  'Rousselle Naomi',
#  'Saindou Soidrine',
#  'Selvaradjou Richard',
#  'Soumahoro Mohamed-Kevin',
#  'Tellier-Rozen Avatar Adjamé Tellier-RozenAdjamé Tellier-Rozen\tAdjame',
#  'Tran Quoc-Bao',
#  'Wang Chuyang',
#  'Yang Yuhao']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'name' : names, 'note': [0]*len(names)})

# %%
df
# Out:
#                                                  name  note
# 0                                        Bensbia Hugo     0
# 1                                         Clement Tom     0
# 2                                      Lambert Mathis     0
# 3                                       Lanneau Erwan     0
# 4                                           Li Xinyun     0
# 5                                     Macaire Florent     0
# 6                                        Miserey Paul     0
# 7                               Oke-Codjo Houenangnon     0
# 8                                     Paris Guillaume     0
# 9                                      Pendeliau Iman     0
# 10                                          Pham Quan     0
# 11                                     Roche Thibault     0
# 12                                         Romain Noe     0
# 13                                       Rouibah Ryan     0
# 14                                    Rousselle Naomi     0
# ...

# %%
df.to_excel('MIN4.xls')

# %%
pwd
# Out:
# '/home/macbuse/Documents/macbuse.github.io/PROG'

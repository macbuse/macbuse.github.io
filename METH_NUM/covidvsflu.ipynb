# %%
import pandas as pd

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/home/macbuse/TMP/datadownload.xlsx', skiprows=5)
df2 = pd.read_excel('/home/macbuse/TMP/datadownload2.xlsx', skiprows=5)

# %%
df2.columns
# Out:
# Index(['Date', 'Deaths due to flu and pneumonia'], dtype='object')

# %%
df2.iloc[:,1]
# Out:
# 0       938.0
# 1      1277.0
# 2      1241.0
# 3      1162.0
# 4      1084.0
#         ...
# 225       NaN
# 226       NaN
# 227       NaN
# 228       NaN
# 229       NaN
# Name: Deaths due to flu and pneumonia, Length: 230, dtype: float64

# %%
pp = df.iloc[:,3][~df.iloc[:,3].isnull()]
qq = df.iloc[:,4][~df.iloc[:,4].isnull()]

# %%
plt.plot(pp);
plt.plot(qq);

# %%
df[:10]
# Out:
#                   Date  Category          Type  \
# 0  2020-03-13 00:00:00  COVID-19  Total deaths
# 1  2020-03-20 00:00:00  COVID-19  Total deaths
# 2  2020-03-27 00:00:00  COVID-19  Total deaths
# 3  2020-04-03 00:00:00  COVID-19  Total deaths
# 4  2020-04-10 00:00:00  COVID-19  Total deaths
# 5  2020-04-17 00:00:00  COVID-19  Total deaths
# 6  2020-04-24 00:00:00  COVID-19  Total deaths
# 7  2020-05-01 00:00:00  COVID-19  Total deaths
# 8  2020-05-08 00:00:00  COVID-19  Total deaths
# 9  2020-05-15 00:00:00  COVID-19  Total deaths
#
#    Deaths involving but not due to  Deaths due to
# 0                              0.0            5.0
# 1                             11.0           96.0
# 2                             33.0          520.0
# 3                            170.0         3334.0
# 4                            254.0         5989.0
# 5                            371.0         8431.0
# 6                            421.0         7873.0
# ...
